# %%
# !bash
# Out:
# bash: cannot set terminal process group (1070): Inappropriate ioctl for device
# bash: no job control in this shell
# /content# ls
# sample_data
# /content# cd sample_data
# /content/sample_data# ll
# total 55512
# drwxr-xr-x 1 root root     4096 May 17 20:41 ./
# drwxr-xr-x 1 root root     4096 May 17 20:41 ../
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json*
# -rw-r--r-- 1 root root   301141 May 17 20:41 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 May 17 20:41 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 May 17 20:41 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 May 17 20:41 mnist_train_small.csv
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md*
# /content/sample_data# cat README.md
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
# ...
