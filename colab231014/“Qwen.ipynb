# %%
# 通义千问7B 一键部署
# 本脚本基于colab测试通过，因为大部分用户是免费用户，只能分到T4显卡，因此模型做了int8量化。

# !git clone -b v1.0.8 https://github.com/Dao-AILab/flash-attention
# %cd flash-attention && pip install .
# %cd ..

# !git clone https://github.com/fishfl/Qwen-7B.git
# %cd Qwen-7B
# !pip install -r requirements.txt
# !pip install -r requirements_web_demo.txt
# !pip install bitsandbytes
# !python web_demo.py --share --checkpoint-path tangger/Qwen-7B-Chat
# !python web_demo.py --share --checkpoint-path Norquinal/Qwen-7B-reupload
# !python web_demo.py --share --checkpoint-path bibimbap/Qwen-7B
# !python web_demo.py --share --checkpoint-path openerotica/Qwen-7b
# !python web_demo.py --share --checkpoint-path chiayewken/Qwen-7B/
# !python web_demo.py --share --checkpoint-path frankminors123/Qwen-7B-Chat
# Out:
# Cloning into 'flash-attention'...
# remote: Enumerating objects: 4033, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 4033 (delta 31), reused 46 (delta 22), pack-reused 3955
# Receiving objects: 100% (4033/4033), 6.90 MiB | 27.48 MiB/s, done.
# Resolving deltas: 100% (2699/2699), done.
# Note: switching to '9610114ce8fc16923b09515d2c2f8c1ac7459f0a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# ...
